# %% [markdown]
# <a href="https://colab.research.google.com/github/Sharad-t/Default_of_Credit_Card/blob/main/Notebook_CCDD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -**Default of Credit Card**

# %% [markdown]
# ##### **Project Type**    - Classification
# ##### **Contribution**    - Individual
# ##### **NAME -Sharad Tiwari**
# ##### **Data Science Trainee**
# ##### **AlmaBetter**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# 1. Imported All of the Required Libraries
# 2. Load the Data into a Dataframe
# 3. Checked for missing Values and NaN Values
# 4. getting the Statistical Information about the Dataset
# 5. Checked for the Duplicate values as well
# 6. Done Some experiments with data Visualization for getting some insights about the data distribution and corelation between the variables
# 7. prepared Heatmap for finding out the corelation
# 8. Checked and treated Outliers
# 9. Done Three Hypothesis Test to obtain p value
# 10. Done feature engineering with Categorical encoding and handled the imbalanced Dataset by undersampling.
#
# 11. **Machine Learning Part**
#
# * Created a dataframe with equal numbers of fraud and non fraud transaction.
# * Splitted the Training and Testing Datasets
# * Implemeted Decision tree Classifier then hyperparameter tuned it With the help of cross validation.
# * Implemeted Logistic Regression then hyperparameter tuned it with the help of cross validation.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# **https://github.com/Sharad-t/Default_of_Credit_Card**

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **“Fraud detection is a set of activities that are taken to prevent money or property from being obtained through false pretenses.”**
#
# Fraud can be committed in different ways and in many industries. The majority of detection methods combine a variety of fraud detection datasets to form a connected overview of both valid and non-valid payment data to make a decision. This decision must consider IP address, geolocation, device identification, “BIN” data, global latitude/longitude, historic transaction patterns, and the actual transaction information. In practice, this means that merchants and issuers deploy analytically based responses that use internal and external data to apply a set of business rules or analytical algorithms to detect fraud.
#
# Credit Card Fraud Detection with Machine Learning is a process of data investigation by a Data Science team and the development of a model that will provide the best results in revealing and preventing fraudulent transactions. This is achieved through bringing together all meaningful features of card users’ transactions, such as Date, User Zone, Product Category, Amount, Provider, Client’s Behavioral Patterns, etc. The information is then run through a subtly trained model that finds patterns and rules so that it can classify whether a transaction is fraudulent or is legitimate. All big banks like Chase use fraud monitoring and detection systems.
#
# ***The challenge is to recognize fraudulent credit card transactions so that the customers of credit card companies are not charged for items that they did not purchase.***
#
# **Main challenges involved in credit card fraud detection are:**
#
# * Enormous Data is processed every day and the model build must be fast enough to respond to the scam in time.
# * Imbalanced Data i.e most of the transactions (99.8%) are not fraudulent which makes it really hard for detecting the fraudulent ones
# * Data availability as the data is mostly private.
# * Misclassified Data can be another major issue, as not every fraudulent transaction is caught and reported.
# * Adaptive techniques used against the model by the scammers.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries

import pandas as pd                                                                            # pandas for data manipulation
import numpy as np                                                                             # Numerical python for dealing with maths or arrays
import seaborn as sns                                                                          # Seaborn  for data visualization
import matplotlib.pyplot as plt                                                                # matplotlib for data visualization
# %matplotlib inline

from sklearn.preprocessing import MinMaxScaler                                                 # Min-Max Scaler 
from sklearn.preprocessing import OneHotEncoder                                                # Encode categorical features as a one-hot numeric array.
from sklearn.preprocessing import MultiLabelBinarizer                                          # Transform between iterable of iterables and a multilabel format.

from sklearn import metrics                                                                    # includes score functions, performance metrics and pairwise metrics and distance computations.
from sklearn.metrics import r2_score                                                           # coefficient of determination regression score function.
from sklearn.metrics import mean_squared_error                                                 # Mean squared error regression loss
from sklearn.metrics import accuracy_score                                                     # Accuracy classification score.
from sklearn.metrics import mean_absolute_error                                                # Mean absolute error regression loss.
from sklearn.metrics import log_loss 

from sklearn.model_selection import cross_validate                                             # Cross Validation
from sklearn.model_selection import train_test_split                                           # Train-Test Split for Spliting the Dataset
from sklearn.model_selection import GridSearchCV                                               # Exhaustive search over specified parameter values for an estimator.
from sklearn.model_selection import cross_val_score                                            # Evaluate a score by cross-validation.
from sklearn.model_selection import RepeatedStratifiedKFold                                    # Repeats Stratified K-Fold n times with different randomization in each repetition.
from sklearn.model_selection import RandomizedSearchCV                                         # Randomized search on hyper parameters.

import warnings                                                                                # Warnings for Ignoring Waring Messages
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset

# from google.colab import drive
# drive.mount('/content/drive')
# df = pd.read_csv("/content/drive/MyDrive/Credit_Card_Default_Detection_Capstone Project ML/default of credit card clients.csv")

df = pd.read_csv("G:\My Drive\Credit_Card_Default_Detection_Capstone Project ML\default of credit card clients.csv")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0         0         0         0                           1
# 1      1000         0      2000                           1
# 2      1000      1000      5000                           0
# 3      1100      1069      1000                           0
# 4      9000       689       679                           0
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (30000, 25)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
#  13  BILL_AMT2                   30000 non-null  int64
#  14  BILL_AMT3                   30000 non-null  int64
#  15  BILL_AMT4                   30000 non-null  int64
#  16  BILL_AMT5                   30000 non-null  int64
#  17  BILL_AMT6                   30000 non-null  int64
#  18  PAY_AMT1                    30000 non-null  int64
#  19  PAY_AMT2                    30000 non-null  int64
#  20  PAY_AMT3                    30000 non-null  int64
#  21  PAY_AMT4                    30000 non-null  int64
#  22  PAY_AMT5                    30000 non-null  int64
#  23  PAY_AMT6                    30000 non-null  int64
#  24  default payment next month  30000 non-null  int64
# dtypes: int64(25)
# memory usage: 5.7 MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count

df[df == df.duplicated].sum()
# Out:
# ID                            0.0
# LIMIT_BAL                     0.0
# SEX                           0.0
# EDUCATION                     0.0
# MARRIAGE                      0.0
# AGE                           0.0
# PAY_0                         0.0
# PAY_2                         0.0
# PAY_3                         0.0
# PAY_4                         0.0
# PAY_5                         0.0
# PAY_6                         0.0
# BILL_AMT1                     0.0
# BILL_AMT2                     0.0
# BILL_AMT3                     0.0
# BILL_AMT4                     0.0
# BILL_AMT5                     0.0
# BILL_AMT6                     0.0
# PAY_AMT1                      0.0
# PAY_AMT2                      0.0
# PAY_AMT3                      0.0
# PAY_AMT4                      0.0
# PAY_AMT5                      0.0
# PAY_AMT6                      0.0
# default payment next month    0.0
# dtype: float64

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isna().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
# Visualizing the missing values
ax= sns.heatmap(df.isnull(),cbar=True,cmap='mako')
ax.set_xlabel('Features Names')
# Out:
# Text(0.5, 23.52222222222222, 'Features Names')

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# * **The Dataset has no Missing or Null (Nan) Values**
# * **the Dataset has 30000 Rows and 25 Columns**

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns

df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# std        9.217904      1.123802      1.197186      1.196868      1.169139
# min       21.000000     -2.000000     -2.000000     -2.000000     -2.000000
# 25%       28.000000     -1.000000     -1.000000     -1.000000     -1.000000
# 50%       34.000000      0.000000      0.000000      0.000000      0.000000
# 75%       41.000000      0.000000      0.000000      0.000000      0.000000
# max       79.000000      8.000000      8.000000      8.000000      8.000000
#
#        ...      BILL_AMT4      BILL_AMT5      BILL_AMT6       PAY_AMT1  \
# count  ...   30000.000000   30000.000000   30000.000000   30000.000000
# mean   ...   43262.948967   40311.400967   38871.760400    5663.580500
# std    ...   64332.856134   60797.155770   59554.107537   16563.280354
# min    ... -170000.000000  -81334.000000 -339603.000000       0.000000
# 25%    ...    2326.750000    1763.000000    1256.000000    1000.000000
# 50%    ...   19052.000000   18104.500000   17071.000000    2100.000000
# 75%    ...   54506.000000   50190.500000   49198.250000    5006.000000
# max    ...  891586.000000  927171.000000  961664.000000  873552.000000
#
#            PAY_AMT2      PAY_AMT3       PAY_AMT4       PAY_AMT5  \
# count  3.000000e+04   30000.00000   30000.000000   30000.000000
# mean   5.921163e+03    5225.68150    4826.076867    4799.387633
# std    2.304087e+04   17606.96147   15666.159744   15278.305679
# min    0.000000e+00       0.00000       0.000000       0.000000
# 25%    8.330000e+02     390.00000     296.000000     252.500000
# 50%    2.009000e+03    1800.00000    1500.000000    1500.000000
# 75%    5.000000e+03    4505.00000    4013.250000    4031.500000
# max    1.684259e+06  896040.00000  621000.000000  426529.000000
#
#             PAY_AMT6  default payment next month
# count   30000.000000                30000.000000
# mean     5215.502567                    0.221200
# std     17777.465775                    0.415062
# min         0.000000                    0.000000
# 25%       117.750000                    0.000000
# 50%      1500.000000                    0.000000
# 75%      4000.000000                    0.000000
# max    528666.000000                    1.000000
#
# [8 rows x 25 columns]

# %% [markdown]
# ### Variables Description

# %% [markdown]
# **There are 25 variables**:
#
# • **ID**: ID of each client
#
# • **LIMIT_BAL**: Amount of given credit in NT dollars (includes individual and family/supplementary credit
#
# • **SEX**: Gender (1=male, 2=female)
#
# • **EDUCATION**: (1=graduate school, 2=university, 3=high school, 4=others, 5=unknown, 6=unknown)
#
# • **MARRIAGE**: Marital status (1=married, 2=single, 3=others)
#
# • **AGE**: Age in years
#
# • **PAY_0**: Repayment status in September, 2005 (-1=pay duly, 1=payment delay for one month, 2=payment delay for two months, … 8=payment delay for eight
#
# • **months, 9=payment delay for nine months and above)
#
# • **PAY_2**: Repayment status in August, 2005
#
# • **PAY_3**: Repayment status in July, 2005
#
# • **PAY_4**: Repayment status in June, 2005
#
# • **PAY_5**: Repayment status in May, 2005
#
# • **PAY_6**: Repayment status in April, 2005
#
# • **BILL_AMT1**: Amount of bill statement in September, 2005
#
# • **BILL_AMT2**: Amount of bill statement in August, 2005
#
# • **BILL_AMT3**: Amount of bill statement in July, 2005
#
# • **BILL_AMT4**: Amount of bill statement in June, 2005
#
# • **BILL_AMT5**: Amount of bill statement in May, 2005
#
# • **BILL_AMT6**: Amount of bill statement in April, 2005
#
# • **PAY_AMT1**: Amount of previous payment in September, 2005
#
# • **PAY_AMT2**: Amount of previous payment in August, 2005
#
# • **PAY_AMT3**: Amount of previous payment in July, 2005
#
# • **PAY_AMT4**: Amount of previous payment in June, 2005
#
# • **PAY_AMT5**: Amount of previous payment in May, 2005
#
# • **PAY_AMT6**: Amount of previous payment in April, 2005
#
#
# • **default.payment.next.month**: Default payment (1=yes, 0=no)

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df.nunique()
# Out:
# ID                            30000
# LIMIT_BAL                        81
# SEX                               2
# EDUCATION                         7
# MARRIAGE                          4
# AGE                              56
# PAY_0                            11
# PAY_2                            11
# PAY_3                            11
# PAY_4                            11
# PAY_5                            10
# PAY_6                            10
# BILL_AMT1                     22723
# BILL_AMT2                     22346
# BILL_AMT3                     22026
# BILL_AMT4                     21548
# BILL_AMT5                     21010
# BILL_AMT6                     20604
# PAY_AMT1                       7943
# PAY_AMT2                       7899
# PAY_AMT3                       7518
# PAY_AMT4                       6937
# PAY_AMT5                       6897
# PAY_AMT6                       6939
# default payment next month        2
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# Dropping ID Column because it doesnt contribute enough its like another index

df.drop(labels='ID',inplace=True,axis=1)

# Sort the repayment status codes in PAY_X columns by melting them into 1 column

# Notice there are 2 undocumented codes: 0,-2

pay = df[['PAY_0','PAY_2','PAY_3','PAY_4','PAY_5','PAY_6']]
pay_melt = pd.melt(pay)
print(pay_melt['value'].value_counts())


# Change inconsistent column names "PAY_0" to 'PAY_1', 'default.payment.next.month'to 'DEF_PAY_NMO'

df.rename(columns={'PAY_0':'PAY_1','default payment next month':'DEF_PAY_NMO'},inplace = True)

#Get the proportion of customers who had default payment in the next month (Oct.2005)? 
# About 22% customers had default payment next month

df['DEF_PAY_NMO'].value_counts(normalize=True)
# Out:
#  0    95919
# -1    34640
# -2    24415
#  2    18964
#  1     3722
#  3     1430
#  4      453
#  7      218
#  5      137
#  6       74
#  8       28
# Name: value, dtype: int64
# 0    0.7788
# 1    0.2212
# Name: DEF_PAY_NMO, dtype: float64

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# * **What do 0 and -2 mean in PAY_X columns?**
#
# From dataset documentation: PAY_0: Repayment status in September, 2005 (-1=pay duly, 1=payment delay for one month, 2=payment delay for two months, … 8=payment delay for eight months, 9=payment delay for nine months and above). Notice code 0 and 2 are in the PAY_X columns but are not included in the data description. Also by doing the value_counts, it shows 0 is the most frequent observation.
#
# After searching online, I realized the same question was asked by others, and the answer from the dataset contributor was:
#
# -2: No consumption;
# -1: Paid in full;
# 0: The use of revolving credit, meaning the payment wasn't due, which makes sense that most customers were using the revolving credit.
#
# * **What does 'default payment next month' mean?**
#
# Is it a predictor or actual data that was collected in the next month - Oct. 2005? According to the reply from the dataset contributor,it seems this is the actual data collected in the next month. "Y: client's behavior; Y=0 then not default, Y=1 then default". This information could be used to test the accuracy of the model that will be built.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code

# Use histogram to view the distribution of credit limit

plt.hist(df["LIMIT_BAL"])
plt.xlabel('Credit_Limit', fontweight='bold')
plt.ylabel('No of Customers', fontweight='bold')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **My objective here is to find out the distribution of credit limit**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Found that the distribution of the credit limit goes upto around 70000**

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code

# Use boxplot to identify any outlier in credit limit

df["LIMIT_BAL"].plot(kind="box")
plt.xlabel('Credit limit in NT$', fontweight='bold')
plt.ylabel('# of Customers', fontweight='bold')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **the objective is to find the outlier in the Credit limit and the boxplot meant to be the best plot for finding out the outliers**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Outlier has been found in the credit limit**

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code

def0 = df.loc[df['DEF_PAY_NMO'] == 0,'LIMIT_BAL']
def1 = df.loc[df['DEF_PAY_NMO'] == 1,'LIMIT_BAL']

fig, ax = plt.subplots()
ax.boxplot([def0, def1],  showfliers=False)

ax.set_xticklabels(['No_default',"Default"],fontweight ='bold')
ax.set_ylabel('Credit limit',fontweight ='bold')
ax.set_title('Credit limit & default next month',fontweight ='bold')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **to check the categorical variable distrbution or displaying 2 charts in one area we use sub plot**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  Make a boxplot to visualize credit limit and default payment next month
#  1: default next month; 0: no default next month

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code

sns.barplot(data=df,x= 'SEX',y='AGE', hue='DEF_PAY_NMO')
# Out:
# <AxesSubplot: xlabel='SEX', ylabel='AGE'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar plots are used to check the distribution of the data my objective is to check the genders in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# I have found out that the number of males are slightly higher than females

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insight which have found does not seem to land an impact on business because its not as much the difference the males are slighty higher in nos

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization 

sns.scatterplot(x=df['AGE'],y=df['DEF_PAY_NMO'])
# Out:
# <AxesSubplot: xlabel='AGE', ylabel='DEF_PAY_NMO'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# My goal is to find the relationship of the featues with the output variable , and scatter plots are mostly used to find the relation between two variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There is no proper relation between the age and the Default payment next month

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12,6))
s = sns.boxplot(ax = ax1, x="SEX", y="LIMIT_BAL", hue="SEX",data=df, palette="PRGn",showfliers=True)
s = sns.boxplot(ax = ax2, x="SEX", y="LIMIT_BAL", hue="SEX",data=df, palette="PRGn",showfliers=False)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **For checking the Credit limit vs sex**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **The limit credit amount is quite balanced between sexes. The males have a slightly smaller Q2 and larger Q3 and Q4 and a lower mean. The female have a larger outlier max value (1M NT dollars)**

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
fig, ax1 = plt.subplots(ncols=1, figsize=(8,6))
s = sns.boxplot(ax = ax1, x="MARRIAGE", y="AGE", hue="SEX",data=df, palette="PRGn",showfliers=False)
s.set_xticklabels(s.get_xticklabels(),rotation=90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Subplots are the best for checking the relationship between two charts or more Variable at once

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **It looks like Married status 3 (others), with mean values over 40 and Q4 values over 60 means mostly vidowed or divorced whilst Married status 0 could be not specified or divorced, as Q1 values are above values for married of both sexes.**
#
# **Married males have mean age above married women. Unmarried males have mean value for age above unmarried women as well but closer. Q3 abd Q4 values for married man are above corresponding values for married women.**

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
fig, ax1 = plt.subplots(ncols=1, figsize=(12,6))
s = sns.boxplot(ax = ax1, x="EDUCATION", y="AGE", hue="MARRIAGE",data=df, palette="PRGn",showfliers=False)
s.set_xticklabels(s.get_xticklabels(),rotation=90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# subplots are used to generate more graphs in one area and its quite insight gaining to see all graphs in one area

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
fig, ax1 = plt.subplots(ncols=1, figsize=(16,6))
s = sns.boxplot(ax = ax1, x="AGE", y="LIMIT_BAL", hue="SEX",data=df, palette="PRGn",showfliers=False)
s.set_xticklabels(s.get_xticklabels(),rotation=90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Mean, Q3 and Q4 values are increasing for both male and female with age until aroung 35 years and then they are oscilating and get to a maximum of Q4 for males at age 64.**
#
# **Mean values are generally smaller for males than for females, with few exceptions, for example at age 39, 48, until approximately 60, where mean values for males are generally larger than for females.**

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
fig, ax1 = plt.subplots(ncols=1, figsize=(12,6))
s = sns.boxplot(ax = ax1, x="MARRIAGE", y="LIMIT_BAL", hue="EDUCATION",data=df, palette="PRGn",showfliers=False)
s.set_xticklabels(s.get_xticklabels(),rotation=90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
plt.figure(figsize = (14,6))
plt.title('Amount of credit limit - Density Plot')
sns.set_color_codes("pastel")
sns.distplot(df['LIMIT_BAL'],kde=True,bins=200, color="blue")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Distribution plots are used to find out the Distribution of the Variable thats why i choose dist plot for finding the distribution of Limit Balance Variable

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The Data is not Normally Distributed its kind off Skewed

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

var = ['BILL_AMT1','BILL_AMT2','BILL_AMT3','BILL_AMT4','BILL_AMT5','BILL_AMT6']

plt.figure(figsize = (8,8))
plt.title('Amount of bill statement (Apr-Sept) \ncorrelation plot (Pearson)')
corr = df[var].corr()
sns.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns,linewidths=.1,vmin=-1, vmax=1)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I wanted to find out the corelation between the Bill Amt from april to september and the best way to check corelation is heatmap

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Correlation is decreasing with distance between months. Lowest correlations are between Sept-April.**

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
var = ['PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5']

plt.figure(figsize = (8,8))
plt.title('Amount of previous payment (Apr-Sept) \ncorrelation plot (Pearson)')
corr = df[var].corr()
sns.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns,linewidths=.1,vmin=-1, vmax=1)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# my goal was to check the corelation between the pay Amt from april to september thats why i choose heatmap for getting the insights about the corelation between those Variables

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **There are no correlations between amounts of previous payments for April-Sept 2005**

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

plt.figure(figsize=(20,10))
correlation=df.corr()
mask = np.triu(np.ones_like(correlation, dtype=bool))
sns.heatmap((correlation),mask=mask, annot=True,cmap='mako',vmin= -1.0,square=False)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# heatmap is used to find out  the corelation between the features and my objective is the same.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Bill amounts are Negetively corelated with our output feature DEF_PAY_NMO
# * PAY is also positively corelated with output feature
# * other than these feature no other feature has strong corelation

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code

# sns.pairplot(vars=[ 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6'], hue='LIMIT_BAL',data=df)
# plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pair Plots are the best plots to find the relations between all of the Variables at one place and it also gives us the distribution insights of all the variables

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# I have observed that there is no strong corelation but pay_[1,2,4,5,6] have a little positive corelation with the payment next month(DEF_PAY_NMO)

# %% [markdown]
# ## ***5. Hypothesis Testing***

# %% [markdown]
# ### Based on your chart experiments, define three hypothetical statements from the dataset. In the next three questions, perform hypothesis testing to obtain final conclusion about the statements through your code and statistical testing.

# %% [markdown]
# ### Hypothetical Statement - 1

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# **Null Hypothesis** - The mean of population Default payment is same as the sample mean
#
# **Alternate hypothesis** - The mean of population Default payment is different from the sample mean

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# Getting a sample from the population


sample_limit = df.LIMIT_BAL.sample(n=6000)

# %%
# Importing Test

from scipy.stats import ttest_1samp

pop_mean  =df.LIMIT_BAL.mean()

# Implementing test

test,pvalue = ttest_1samp(sample_limit,popmean=pop_mean)

print(pvalue)

# Checking if we accept or reject the null Hypothesis

if pvalue >0.05:
    print('We are rejecting Null Hypothesis \nbecause there is a small difference between the sample mean and population mean')
else:
    print('We are Accepting Null Hypothesis \nbecause there is a no difference between the sample mean and population mean')
# Out:
# 0.887965329778591
# We are rejecting Null Hypothesis
# because there is a small difference between the sample mean and population mean

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# **As  i am performing the test on single numeric variable i am using one sample t-test**

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# **My Goal is to check the hypothesis of the differenciation of mean if i take a sample out of out dataset**

# %% [markdown]
# ### Hypothetical Statement - 2

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# **Null Hypothesis** - There is a strong corelation between the Education and limit Balance
#
# **Alternate hypothesis**- There is no strong corelation between the Education and limit Balance

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# importing Test

from scipy.stats import pearsonr

# Implementing the test
stat_,P_value = pearsonr(df.EDUCATION,df.LIMIT_BAL) 

# Checking if we accept or reject the null Hypothesis

if P_value >0.05:
    print('We are rejecting Null Hypothesis \nthere is strong corelation')
else:
    print('We are Accepting Null Hypothesis \nthere is no strong corelation')
# Out:
# We are Accepting Null Hypothesis
# there is no strong corelation

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# I have used ***Pearson Corelation*** test this test is used to find the Corelation Between the Variables

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# The Motive is to find out that if there is a strong corelation between the Education and the Limit Balance Variable, thats the Reason i have to the Pearsons corelation Test

# %% [markdown]
# ### Hypothetical Statement - 3

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# **Null Hypothesis** - The Data is Normally Distributed
#
# **Altenate Hypothesis** - The Data is Not Normally Distributed

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

from scipy.stats import shapiro

# data for Testing

Test_ = df['LIMIT_BAL']

# Implementing the test


stat,p_val = shapiro(Test_)

# Checking if we accept or reject the null Hypothesis

if p_val <0.05:
    print('We are rejecting Null Hypothesis \nhence the Data is not Normally Distributed')
else:
    print('We are Accepting Null Hypothesis \n hence the Data is  Normally Distributed')
# Out:
# We are rejecting Null Hypothesis
# hence the Data is not Normally Distributed

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# I have used ***Shapiro Wik Test*** : This Test is used to find out whether the data is Distributed Normally or not

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# I wanted to find out that if the data is Normally Distributed or not with statistical approach and after some research i found out the Shapiro test

# %% [markdown]
# ## ***6. Feature Engineering & Data Pre-processing***

# %% [markdown]
# ### 1. Handling Missing Values

# %%
# Handling Missing Values & Missing Value Imputation
df.dropna(inplace=True)

# %% [markdown]
# #### What all missing value imputation techniques have you used and why did you use those techniques?

# %% [markdown]
# As the Dataset doesnt have any null or missing value there is no need to use any techniques

# %% [markdown]
# ### 2. Handling Outliers

# %%
# Handling Outliers & Outlier treatments
df.LIMIT_BAL = np.sqrt(df[ 'LIMIT_BAL'])
df['LIMIT_BAL'].plot(kind='box')
# Out:
# <AxesSubplot: >

# %% [markdown]
# ##### What all outlier treatment techniques have you used and why did you use those techniques?

# %% [markdown]
# The Thumb rule to deal with the outliers is to apply the Square Root. there are many other techniques we can use to deal with outliers like imputation with mean or median etc. but i have applied the square root

# %% [markdown]
# ### 3. Categorical Encoding

# %%
# Encode your categorical columns

# Not Needed

# %% [markdown]
# #### What all categorical encoding techniques have you used & why did you use those techniques?

# %% [markdown]
# **As the data is Already Encoded there is no Need to use any techniques for categorical encoding**

# %% [markdown]
# ### Handling Imbalanced Dataset

# %%
# Handling Imbalanced Dataset (If needed)

df['DEF_PAY_NMO'].value_counts()   # The Dataset is highly imbalanced we need to handle it
# Out:
# 0    23364
# 1     6636
# Name: DEF_PAY_NMO, dtype: int64

# %%
# handling Imbalance

# creating the variables which contain the legit and fraud transaction

# Legit Transactions

legit = df[df.DEF_PAY_NMO == 0]

# Fraud Transactions

fraud = df[df.DEF_PAY_NMO == 1]

# %% [markdown]
# ##### Do you think the dataset is imbalanced? Explain Why.

# %% [markdown]
# Yes the Dataset is highly imbalanced we have 23364 entries of not fraudulent transaction and only 6636 of fraudulent transaction if we feed this data to the algorithms the model will not be able to perform as per the requirement

# %%
# Taking out the sample dataset containing similar distrubution from the legit and fraud transaction

# Under Sampling from the Legit Transaction

legit_sample = legit.sample(n= 6636)

# Concatenating the Dataframes

df1 = pd.concat([legit_sample , fraud],axis=0)

df1.reset_index()

df1.DEF_PAY_NMO.value_counts()
# Out:
# 0    6636
# 1    6636
# Name: DEF_PAY_NMO, dtype: int64

# %% [markdown]
# ##### What technique did you use to handle the imbalance dataset and why? (If needed to be balanced)

# %% [markdown]
# **I have used Under-Sampling Technique to balance the Dataset for feeding the data to the algorithms**

# %% [markdown]
# ### 4. Feature Manipulation & Selection

# %% [markdown]
# #### 1. Feature Manipulation

# %%
# Manipulate Features to minimize feature correlation and create new features

df1.corr()
# as the data doesnt have good corelation with the other variables we need to take all of the variables
# Out:
#              LIMIT_BAL       SEX  EDUCATION  MARRIAGE       AGE     PAY_1  \
# LIMIT_BAL     1.000000  0.040375  -0.243432 -0.113866  0.140724 -0.296481
# SEX           0.040375  1.000000   0.017688 -0.026547 -0.087395 -0.051253
# EDUCATION    -0.243432  0.017688   1.000000 -0.139591  0.172680  0.108645
# MARRIAGE     -0.113866 -0.026547  -0.139591  1.000000 -0.408548  0.008352
# AGE           0.140724 -0.087395   0.172680 -0.408548  1.000000 -0.031371
# PAY_1        -0.296481 -0.051253   0.108645  0.008352 -0.031371  1.000000
# PAY_2        -0.333472 -0.065441   0.131741  0.016989 -0.043331  0.672416
# PAY_3        -0.327713 -0.067237   0.123690  0.025138 -0.040832  0.574491
# PAY_4        -0.311205 -0.062162   0.120035  0.017448 -0.037311  0.537195
# PAY_5        -0.294427 -0.061662   0.106566  0.020534 -0.040378  0.504964
# PAY_6        -0.275821 -0.044872   0.093492  0.024460 -0.040797  0.477906
# BILL_AMT1     0.313760 -0.025180   0.017955 -0.033660  0.058501  0.174659
# BILL_AMT2     0.306332 -0.024225   0.011177 -0.030190  0.056859  0.178994
# BILL_AMT3     0.304903 -0.016881   0.005182 -0.032379  0.055936  0.169318
# BILL_AMT4     0.310103 -0.015908  -0.006700 -0.032203  0.055651  0.181239
# BILL_AMT5     0.314333 -0.012090  -0.011960 -0.033695  0.056813  0.183724
# BILL_AMT6     0.307661 -0.013140  -0.012867 -0.034165  0.056019  0.181444
# PAY_AMT1      0.171108  0.008470  -0.032198  0.004226  0.022900 -0.089744
# PAY_AMT2      0.151027  0.004954  -0.024153 -0.004258  0.017699 -0.069425
# PAY_AMT3      0.181854 -0.009216  -0.042763  0.011582  0.008500 -0.063858
# PAY_AMT4      0.188206  0.004916  -0.034823  0.002613  0.011256 -0.070587
# PAY_AMT5      0.200642 -0.009031  -0.026414 -0.008440  0.017214 -0.050984
# PAY_AMT6      0.200461 -0.001699  -0.035906  0.005104  0.013997 -0.056091
# DEF_PAY_NMO  -0.203354 -0.036856   0.045491 -0.028200  0.015999  0.339870
#
#                 PAY_2     PAY_3     PAY_4     PAY_5  ...  BILL_AMT4  \
# LIMIT_BAL   -0.333472 -0.327713 -0.311205 -0.294427  ...   0.310103
# SEX         -0.065441 -0.067237 -0.062162 -0.061662  ...  -0.015908
# EDUCATION    0.131741  0.123690  0.120035  0.106566  ...  -0.006700
# MARRIAGE     0.016989  0.025138  0.017448  0.020534  ...  -0.032203
# AGE         -0.043331 -0.040832 -0.037311 -0.040378  ...   0.055651
# PAY_1        0.672416  0.574491  0.537195  0.504964  ...   0.181239
# PAY_2        1.000000  0.769983  0.657502  0.615967  ...   0.211311
# PAY_3        0.769983  1.000000  0.785188  0.691769  ...   0.210011
# PAY_4        0.657502  0.785188  1.000000  0.832546  ...   0.212402
# PAY_5        0.615967  0.691769  0.832546  1.000000  ...   0.232040
# PAY_6        0.575498  0.642735  0.734003  0.831047  ...   0.237420
# BILL_AMT1    0.205398  0.176707  0.161571  0.161721  ...   0.876650
# BILL_AMT2    0.206946  0.204958  0.183496  0.181639  ...   0.907287
# BILL_AMT3    0.200166  0.199483  0.201648  0.196645  ...   0.921988
# BILL_AMT4    0.211311  0.210011  0.212402  0.232040  ...   1.000000
# BILL_AMT5    0.212271  0.209899  0.213422  0.234232  ...   0.951206
# BILL_AMT6    0.212097  0.209073  0.212921  0.231606  ...   0.911611
# PAY_AMT1    -0.092909 -0.011001 -0.023627 -0.019997  ...   0.218535
# PAY_AMT2    -0.057279 -0.062555 -0.015958 -0.019309  ...   0.162073
# PAY_AMT3    -0.052841 -0.056045 -0.069032  0.003638  ...   0.279102
# PAY_AMT4    -0.050856 -0.055116 -0.047969 -0.060366  ...   0.158502
# PAY_AMT5    -0.032264 -0.040546 -0.039487 -0.035034  ...   0.174126
# PAY_AMT6    -0.036005 -0.039337 -0.031317 -0.027203  ...   0.177397
# DEF_PAY_NMO  0.272448  0.247171  0.226961  0.208543  ...  -0.011341
#
#              BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  \
# LIMIT_BAL     0.314333   0.307661  0.171108  0.151027  0.181854  0.188206
# SEX          -0.012090  -0.013140  0.008470  0.004954 -0.009216  0.004916
# EDUCATION    -0.011960  -0.012867 -0.032198 -0.024153 -0.042763 -0.034823
# MARRIAGE     -0.033695  -0.034165  0.004226 -0.004258  0.011582  0.002613
# AGE           0.056813   0.056019  0.022900  0.017699  0.008500  0.011256
# PAY_1         0.183724   0.181444 -0.089744 -0.069425 -0.063858 -0.070587
# PAY_2         0.212271   0.212097 -0.092909 -0.057279 -0.052841 -0.050856
# PAY_3         0.209899   0.209073 -0.011001 -0.062555 -0.056045 -0.055116
# PAY_4         0.213422   0.212921 -0.023627 -0.015958 -0.069032 -0.047969
# PAY_5         0.234232   0.231606 -0.019997 -0.019309  0.003638 -0.060366
# PAY_6         0.261561   0.260572 -0.012857 -0.013964  0.004111  0.011907
# BILL_AMT1     0.847969   0.817533  0.141283  0.094413  0.155144  0.177930
# BILL_AMT2     0.874128   0.842190  0.257776  0.088891  0.150563  0.161985
# BILL_AMT3     0.888122   0.860528  0.213528  0.307567  0.130965  0.157967
# BILL_AMT4     0.951206   0.911611  0.218535  0.162073  0.279102  0.158502
# BILL_AMT5     1.000000   0.950020  0.211846  0.158094  0.246455  0.293118
# BILL_AMT6     0.950020   1.000000  0.197324  0.165909  0.226149  0.252583
# PAY_AMT1      0.211846   0.197324  1.000000  0.323096  0.345255  0.291042
# PAY_AMT2      0.158094   0.165909  0.323096  1.000000  0.340745  0.284770
# PAY_AMT3      0.246455   0.226149  0.345255  0.340745  1.000000  0.281624
# PAY_AMT4      0.293118   0.252583  0.291042  0.284770  0.281624  1.000000
# PAY_AMT5      0.163332   0.308458  0.097836  0.228695  0.143511  0.142810
# PAY_AMT6      0.160146   0.104560  0.175222  0.168529  0.168893  0.135755
# DEF_PAY_NMO  -0.008968  -0.005770 -0.097918 -0.068985 -0.068519 -0.073510
#
#              PAY_AMT5  PAY_AMT6  DEF_PAY_NMO
# LIMIT_BAL    0.200642  0.200461    -0.203354
# SEX         -0.009031 -0.001699    -0.036856
# EDUCATION   -0.026414 -0.035906     0.045491
# MARRIAGE    -0.008440  0.005104    -0.028200
# AGE          0.017214  0.013997     0.015999
# PAY_1       -0.050984 -0.056091     0.339870
# PAY_2       -0.032264 -0.036005     0.272448
# PAY_3       -0.040546 -0.039337     0.247171
# PAY_4       -0.039487 -0.031317     0.226961
# PAY_5       -0.035034 -0.027203     0.208543
# PAY_6       -0.044619 -0.032053     0.195711
# BILL_AMT1    0.197894  0.189170    -0.021160
# BILL_AMT2    0.175333  0.177888    -0.017279
# BILL_AMT3    0.217521  0.186469    -0.017724
# BILL_AMT4    0.174126  0.177397    -0.011341
# BILL_AMT5    0.163332  0.160146    -0.008968
# BILL_AMT6    0.308458  0.104560    -0.005770
# PAY_AMT1     0.097836  0.175222    -0.097918
# PAY_AMT2     0.228695  0.168529    -0.068985
# PAY_AMT3     0.143511  0.168893    -0.068519
# PAY_AMT4     0.142810  0.135755    -0.073510
# PAY_AMT5     1.000000  0.129708    -0.067353
# PAY_AMT6     0.129708  1.000000    -0.069756
# DEF_PAY_NMO -0.067353 -0.069756     1.000000
#
# [24 rows x 24 columns]

# %% [markdown]
# #### 2. Feature Selection

# %%
# Select your features wisely to avoid overfitting

# The data is not highly corelation thats why we are going to take all of the Variables
df.columns
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_1', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'DEF_PAY_NMO'],
#       dtype='object')

# %% [markdown]
# ##### What all feature selection methods have you used  and why?

# %% [markdown]
# **I have Selected all of the Variables**
#
#
# 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_1', 'PAY_2',
# 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
# BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
# PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
# DEF_PAY_NMO'

# %% [markdown]
# ### 5. Data Transformation

# %%
# Transform Your data

# Independent Features
 
X = df1.drop(columns=['DEF_PAY_NMO'], axis=1)

# Dependent Feature
y = df1['DEF_PAY_NMO']

# %% [markdown]
# ### 6. Data Scaling

# %%
# Scaling your data

# importing MinMaxScaler from sklearn

from sklearn.preprocessing import MinMaxScaler

# initializing the Scaler

min_max = MinMaxScaler()

# Transforming the data

min_max.fit_transform(df1)
# Out:
# array([[3.93126728e-01, 0.00000000e+00, 3.33333333e-01, ...,
#         3.42344571e-01, 9.46344195e-03, 0.00000000e+00],
#        [0.00000000e+00, 1.00000000e+00, 3.33333333e-01, ...,
#         1.36315262e-03, 9.45776729e-04, 0.00000000e+00],
#        [4.37061570e-01, 1.00000000e+00, 3.33333333e-01, ...,
#         9.81779107e-04, 7.33922741e-03, 0.00000000e+00],
#        ...,
#        [9.21482567e-02, 0.00000000e+00, 3.33333333e-01, ...,
#         5.15369610e-03, 5.86381572e-03, 1.00000000e+00],
#        [2.30156665e-01, 0.00000000e+00, 5.00000000e-01, ...,
#         1.36480180e-01, 3.41236244e-03, 1.00000000e+00],
#        [1.55592355e-01, 0.00000000e+00, 3.33333333e-01, ...,
#         2.57684805e-03, 1.89155346e-03, 1.00000000e+00]])

# %% [markdown]
# ##### Which method have you used to scale you data and why?

# %% [markdown]
# **I have used MinMax Scaler for Scaling the data Because MinMax Scaler Minimizes the data Between 0 to 1 and for the data we have it is a good decision to use Min Max Scaler**

# %% [markdown]
# ### 7. Dimesionality Reduction

# %% [markdown]
# ##### Do you think that dimensionality reduction is needed? Explain Why?

# %% [markdown]
# Not Needed

# %%
# DImensionality Reduction (If needed)

# in this data set we donr need to use dimensity reduction as dimensity reduction is used in unsupervised ML mainly

# %% [markdown]
# ##### Which dimensionality reduction technique have you used and why? (If dimensionality reduction done on dataset.)

# %% [markdown]
# **Dimensity Reduction is not important for this type of dataset thus we are not going to use any Dimensity reduction techniques**

# %% [markdown]
# ### 8. Data Splitting

# %%
# Split your data to train and test. Choose Splitting ratio wisely.


# importing train_test_split from Sklearn

from sklearn.model_selection import train_test_split

# Splitting the Data

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=33)

# %% [markdown]
# ##### What data splitting ratio have you used and why?

# %% [markdown]
# I will be using the Thumb Rule of (80, 20) 80% of data to Train set and the remaining 20% data to the test set

# %% [markdown]
# ## ***7. ML Model Implementation***

# %% [markdown]
# ### ML Model - 1 Decision tree Classifier

# %%
# ML Model - 1 Implementation

from sklearn.tree import DecisionTreeClassifier

DT_Model = DecisionTreeClassifier()

# Fit the Algorithm

DT_Model.fit(X_train,y_train)

# Predict on the model
y_pred_DT = DT_Model.predict(X_test)

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# # Visualizing evaluation Metric Score chart
from sklearn.metrics import accuracy_score

# Checking the Accuracy score
score = accuracy_score(y_test,y_pred_DT)

print('Accuracy score',score)

MSE  = mean_squared_error(10**(y_test), 10**(y_pred_DT))
print("MSE :" , MSE)

RMSE = np.sqrt(MSE)
print("RMSE :" ,RMSE)

r2 = r2_score(10**(y_test), 10**(y_pred_DT))
print("R2 :" ,r2)
print("Adjusted R2 : ",1-(1-r2_score(10**(y_test), 10**(y_pred_DT)))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)))
# Out:
# Accuracy score 0.6120527306967984
# MSE : 31.423728813559322
# RMSE : 5.605687184775772
# R2 : -0.5523618788764348
# Adjusted R2 :  -0.5659325072360541

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Initializing the Parameters 

parameters = {'criterion':['gini','entropy'],"max_depth": range(1,10),"min_samples_split": range(1,10),"min_samples_leaf": range(1,5)}

# Importing GridSearchCV

from sklearn.model_selection import GridSearchCV

# Creating Instance
DT_GS = GridSearchCV(estimator=DT_Model,param_grid=parameters,cv=10,verbose=1,n_jobs=-1)

# Fit the Algorithm
DT_GS.fit(X_train,y_train)
# Out:
# Fitting 10 folds for each of 648 candidates, totalling 6480 fits
# GridSearchCV(cv=10, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(1, 10),
#                          'min_samples_leaf': range(1, 5),
#                          'min_samples_split': range(1, 10)},
#              verbose=1)

# %%
# Predict on the model

DT_Model_tuned = DT_GS.best_estimator_

# fitting the data to best estimator

DT_Model_tuned.fit(X_train,y_train)

# Prediction
y_pred_DT_tuned =DT_Model_tuned.predict(X_test) 

# Checking Accuracy Score
accuracy_score(y_test,y_pred_DT_tuned)
# Out:
# 0.6983050847457627

# %%
# Evaluation Metrics after hyperparameter tuning

score = accuracy_score(y_pred_DT_tuned,y_test)
print('Accuracy score',score)


MSE  = mean_squared_error(10**(y_test), 10**(y_pred_DT_tuned))
print("MSE :" , MSE)

RMSE = np.sqrt(MSE)
print("RMSE :" ,RMSE)

r2 = r2_score(10**(y_test), 10**(y_pred_DT_tuned))
print("R2 :" ,r2)
print("Adjusted R2 : ",1-(1-r2_score(10**(y_test), 10**(y_pred_DT_tuned)))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)))
# Out:
# Accuracy score 0.6983050847457627
# MSE : 24.43728813559322
# RMSE : 4.9434085543876725
# R2 : -0.20722511163109147
# Adjusted R2 :  -0.21777858086997992

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# **I have used GridsearchCV for Cross validation for finding out the best parameters**
#
# **GridSearchCV helps to loop through predefined hyperparameters and fit the model on the training set. So, in the end, we can select the best parameters from the listed hyperparameters.**

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# **I have seen a little improvement in accuracy score before Cross validation the score is 60% and after the Cross Validation it is 70%**
#
# Accuracy score 0.7082191780821918
#
# MSE : 23.634246575342466
#
# RMSE : 4.8615066157871745
#
# R2 : -0.1673279795731577
#
# Adjusted R2 :  -0.17349155705942554

# %% [markdown]
# ### ML Model - 2 Logistic Regression

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# ML Model - 1 Implementation

# Importing Model 

from sklearn.linear_model import LogisticRegression

# Initializing the Model

LGR_model = LogisticRegression()

# Model Training

LGR_model.fit(X_train,y_train)

# Prediction 
y_pred_LGR=LGR_model.predict(X_test)

# %%
# Visualizing evaluation Metric Score chart

score = accuracy_score(y_pred_LGR,y_test)

print('Accuracy score',score)

MSE  = mean_squared_error(10**(y_test), 10**(y_pred_LGR))
print("MSE :" , MSE)

RMSE = np.sqrt(MSE)
print("RMSE :" ,RMSE)

r2 = r2_score(10**(y_test), 10**(y_pred_LGR))
print("R2 :" ,r2)
print("Adjusted R2 : ",1-(1-r2_score(10**(y_test), 10**(y_pred_LGR)))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)))
# Out:
# Accuracy score 0.5468926553672316
# MSE : 36.70169491525424
# RMSE : 6.058192380178616
# R2 : -0.8130983886294672
# Adjusted R2 :  -0.8289483555388089

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Initializing the Parameters 

cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)

# define search space

space = dict()
space['solver'] = ['newton-cg', 'lbfgs', 'liblinear']
space['penalty'] = ['none', 'l1', 'l2', 'elasticnet']

LGR_model_tuned = RandomizedSearchCV(LGR_model, space, n_iter=500, scoring='accuracy', n_jobs=-1, cv=cv, random_state=1)

# %%
# Fitting the Data to tuned model
LGR_model_tuned.fit(X_train,y_train)

# Prediction on tuned model
y_pred_LGR_tuned = LGR_model_tuned.predict(X_test)

# %%
# Evaluation Metrics after hyperparameter tuning

score = accuracy_score(y_pred_LGR_tuned,y_test)

print('Accuracy score',score)

MSE  = mean_squared_error(10**(y_test), 10**(y_pred_LGR_tuned))
print("MSE :" , MSE)

RMSE = np.sqrt(MSE)
print("RMSE :" ,RMSE)

r2 = r2_score(10**(y_test), 10**(y_pred_LGR_tuned))
print("R2 :" ,r2)
print("Adjusted R2 : ",1-(1-r2_score(10**(y_test), 10**(y_pred_LGR_tuned)))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)))
# Out:
# Accuracy score 0.6741996233521658
# MSE : 26.389830508474578
# RMSE : 5.137103318843663
# R2 : -0.3036825487651613
# Adjusted R2 :  -0.31507924151377376

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# **I have used RandomizedSearchCV for Cross validation for finding out the best parameters**
#
# **RandomizedSearchCV implements a “fit” and a “score” method. It also implements “score_samples”, “predict”, “predict_proba”, “decision_function”, “transform” and “inverse_transform” if they are implemented in the estimator used.**

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Accuracy score 0.6726027397260274
#
# MSE : 26.519178082191782
#
# RMSE : 5.149677473608593
#
# R2 : -0.30981871886377776
#
# Adjusted R2 :  -0.3167346579211392

# %% [markdown]
# #### 3. Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### ML Model - 3 XGBoost Classifier

# %%
# ML Model - 3 Implementation

# Importing the Model

from xgboost import XGBClassifier

# Initializing the Model

XGB_Model = XGBClassifier(eta =0.01,gamma =10)

# Fit the Algorithm

XGB_Model.fit(X_train,y_train)

# Predict on the model

y_pred_XGB =  XGB_Model.predict(X_test)

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

score = accuracy_score(y_pred_XGB,y_test)

print('Accuracy score',score)

MSE  = mean_squared_error(10**(y_test), 10**(y_pred_XGB))
print("MSE :" , MSE)

RMSE = np.sqrt(MSE)
print("RMSE :" ,RMSE)

r2 = r2_score(10**(y_test), 10**(y_pred_XGB))
print("R2 :" ,r2)
print("Adjusted R2 : ",1-(1-r2_score(10**(y_test), 10**(y_pred_XGB)))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)))
# Out:
# Accuracy score 0.7016949152542373
# MSE : 24.16271186440678
# RMSE : 4.915558143731674
# R2 : -0.19366078453411295
# Adjusted R2 :  -0.2040956754669465

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 3 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)
params = {
        'min_child_weight': [1, 5, 10],
        'gamma': [0.5, 1, 1.5, 2, 5],
        'subsample': [0.6, 0.8, 1.0],
        'colsample_bytree': [0.6, 0.8, 1.0],
        'max_depth': [3, 4, 5]
        }


skf = StratifiedKFold(n_splits=3, shuffle = True, random_state = 1001)

XGB_Model_tuned = RandomizedSearchCV(XGB_Model, param_distributions=params, n_iter=5, scoring='roc_auc', n_jobs=4, cv=5, verbose=3, random_state=100 )

# Fit the Algorithm
XGB_Model_tuned.fit(X_train,y_train)

# Predict on the model
y_pred_XGB_tuned = XGB_Model_tuned.predict(X_test)
# Out:
# Fitting 10 folds for each of 5 candidates, totalling 50 fits

# %%
# Visualizing evaluation Metric Score chart afte hyperparameter Tuning

score = accuracy_score(y_pred_XGB_tuned,y_test)

print('Accuracy score',score)

MSE  = mean_squared_error(10**(y_test), 10**(y_pred_XGB_tuned))
print("MSE :" , MSE)

RMSE = np.sqrt(MSE)
print("RMSE :" ,RMSE)

r2 = r2_score(10**(y_test), 10**(y_pred_XGB_tuned))
print("R2 :" ,r2)
print("Adjusted R2 : ",1-(1-r2_score(10**(y_test), 10**(y_pred_XGB_tuned)))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)))
# Out:
# Accuracy score 0.7062146892655368
# MSE : 23.796610169491526
# RMSE : 4.878176930933474
# R2 : -0.175575015071475
# Adjusted R2 :  -0.18585180159623516

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# **I have used RandomizedSearchCV for Cross validation for finding out the best parameters**
#
# **RandomizedSearchCV implements a “fit” and a “score” method. It also implements “score_samples”, “predict”, “predict_proba”, “decision_function”, “transform” and “inverse_transform” if they are implemented in the estimator used.**

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Accuracy score 0.7107344632768362
#
# MSE : 23.43050847457627
#
# RMSE : 4.840507047260263
#
# R2 : -0.15748924560883681
#
# Adjusted R2 :  -0.1676079277255238

# %% [markdown]
# ### 3. Explain the model which you have used and the feature importance using any model explainability tool?

# %% [markdown]
# **I am Using Shap for the Explaination of the XGBoost Classifier Model and The Importance of all the features**

# %%
import shap

explainer = shap.Explainer(XGB_Model,X_test)
shap_values = explainer.shap_values(X_test)
shap.summary_plot(shap_values,X_test)

# %% [markdown]
# ## ***8.*** ***Future Work (Optional)***

# %% [markdown]
# ### 1. Save the best performing ml model in a pickle file or joblib file format for deployment process.

# %%
# Save the File

import joblib

joblib.dump(XGB_Model, 'XGBoost Best Performer')
# Out:
# ['XGBoost Best Performer']

# %% [markdown]
# ### 2. Again Load the saved model file and try to predict unseen data for a sanity check.

# %%
# Load the File and predict unseen data.

joblib.load('XGBoost Best Performer')
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eta=0.01, eval_metric=None,
#               feature_types=None, gamma=10, gpu_id=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, ...)

# %% [markdown]
# ### ***Congrats! Your model is successfully created and ready for deployment on a live server for a real user interaction !!!***

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
